# %%
import pandas as pd

# %%
cat = pd.read_csv("catalogo_de_dados.csv", on_bad_lines = 'skip')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cat = pd.read_csv("catalogo_de_dados.csv")
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
cat
# Out:
#                                                                                                                                                                                nom_categoria;nom_sub_categoria;des_grupo_dados;cod_orgao_responsavel;nom_orgao_responsavel;nom_conjunto_dados;des_conjunto_dados;txt_url;des_frequencia_atualizacao;dth_ultima_atualizacao;nom_dicionario_dados;des_dicionario_dados;des_tipo_campo;num_ordem
# Administrativo;Contratações;Licitações e Contra...  como                                               por exemplo                         um serviço  um posto de mão de obra   instalação ou fornecimento de um equipamento....
# Administrativo;Contratações;Licitações e Contra...  serviços e funcionários terceirizados para o S...  ato ou fase da licitação realizada  sendo       por exemplo               a HOMOLOGAÇÃO a etapa final da licitação que ...
# ...
