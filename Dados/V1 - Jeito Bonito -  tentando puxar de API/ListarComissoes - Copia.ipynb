# %%
import pandas as pd
import subprocess
import json
import xmltodict
import pprint
import numpy as np
# import  aspose.cells 
# from aspose.cells import Workbook

pd.set_option('max_colwidth',250)
pd.set_option('display.max_rows',90)

# %% [markdown]
# todosCargos = Contem os cargos de cada comissão

# %%
def cargos(lista):
    todosCargos = pd.DataFrame()
    for i,r in lista.iterrows():
        if r["Cargos"] != None:
            for i,cargos in enumerate(r["Cargos"]):
                iteracao = pd.DataFrame.from_dict(cargos,orient='index').T
                iteracao["CodigoColegiado"] = r["CodigoColegiado"]
                todosCargos = pd.concat([iteracao,todosCargos])
    return todosCargos

# %%
comando = 'curl https://legis.senado.leg.br/dadosabertos/dados/ConselhosOrgaosCongresso.xml'
resultado = subprocess.run(comando, shell=True, text=True, capture_output=True)
resultado = resultado.stdout
resultado = json.dumps(xmltodict.parse(resultado))
resultado = pd.read_json(resultado)
resultado = resultado.loc["Colegiados"]["ConselhosOrgaosCongresso"]
resultado = pd.DataFrame(resultado)
lista = pd.DataFrame()
for i,r in resultado.iterrows():
    aux = pd.DataFrame(r.loc["Colegiado"])
    lista = pd.concat([lista, aux], axis=0)
lista = lista.groupby("CodigoColegiado").first().reset_index()
todosCargos = cargos(lista)
# Out:
# C:\Users\kristyan.silva\AppData\Local\Temp\ipykernel_23824\1019879638.py:5: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   resultado = pd.read_json(resultado)

# %%
lista
# Out:
#   CodigoColegiado                                          NomeColegiado  \
# 0            1916     Representação Brasileira no Parlamento do Mercosul
# 1             767                         Conselho de Comunicação Social
# 2             768                Conselho da Ordem do Congresso Nacional
# 3             769  Conselho do Diploma do Mérito Educativo Darcy Ribeiro
#
#   SiglaColegiado  \
# 0          CPCMS
# 1            CCS
# 2           COCN
# 3          DMEDR
#
#                                                                                                                                                                                                                                                   Finalidade  \
# 0                                                                                                      A Representação Brasileira no Parlamento do Mercosul tem por finalidade ser o órgão de ligação entre o Congresso Nacional e o Parlamento do Mercosul.
# 1  O Conselho de Comunicação Social tem como atribuição a realização de estudos, pareceres, recomendações e outras solicitações que lhe forem encaminhadas pelo Congresso Nacional a respeito do Título VIII, Capítulo V, da Constituição Federal (art. 2...
# 2  A Ordem do Congresso Nacional é destinada a prestigiar as pessoas físicas ou jurídicas, nacionais ou estrangeiras, que se tenham tornado dignas do especial reconhecimento do Poder Legislativo do Brasil. Compete ao Conselho aprovar ou rejeitar as ...
# 3                                                                  O Diploma do Mérito Educativo Darcy Ribeiro é entregue pelo Congresso Nacional a pessoas ou instituições que tenham oferecido contribuição relevante para a causa da educação brasileira.
#
#    DataInicio QuantidadesMembros  \
# 0  02/02/2015                 37
# 1  30/12/1991               None
# 2  23/11/1972                 22
# 3  12/08/1999               None
#
#                                                                                                                                                                                                                                                       Cargos  \
# 0  [{'TipoCargo': 'PRESIDENTE', 'CodigoCargo': '1', 'NomeParlamentar': 'Senador Nelsinho Trad', 'CodigoParlamentar': '5985', 'Bancada': '(PSD-MS)'}, {'TipoCargo': '1º VICE-PRESIDENTE', 'CodigoCargo': '4', 'NomeParlamentar': 'Senador Humberto Costa',...
# 1                                       [{'TipoCargo': 'PRESIDENTE', 'CodigoCargo': '1', 'NomeParlamentar': 'Miguel Matos', 'Bancada': '(-)'}, {'TipoCargo': 'VICE-PRESIDENTE', 'CodigoCargo': '2', 'NomeParlamentar': 'Patricia Blanco', 'Bancada': '(-)'}]
# 2                                                                                                                                                                                                                                                       None
# 3                                                                                                                                                                                                                                                       None
#
#                                                                                                                                                                                                                                                      Eventos  \
# 0                                                                                         [{'TipoEvento': 'Designação', 'DataEvento': '11/07/2023', 'OrdemImpressao': '1'}, {'TipoEvento': 'Instalação', 'DataEvento': '13/09/2023', 'OrdemImpressao': '2'}]
# 1  [{'TipoEvento': 'Eleição Geral', 'DataEvento': '05/06/2002', 'OrdemImpressao': '1'}, {'TipoEvento': 'Eleição Geral', 'DataEvento': '22/12/2004', 'OrdemImpressao': '1'}, {'TipoEvento': 'Eleição Geral', 'DataEvento': '17/07/2012', 'OrdemImpressao':...
# 2  [{'TipoEvento': 'Atualização', 'DataEvento': '12/09/2012', 'OrdemImpressao': '8'}, {'TipoEvento': 'Atualização', 'DataEvento': '04/02/2013', 'OrdemImpressao': '8'}, {'TipoEvento': 'Atualização', 'DataEvento': '07/03/2013', 'OrdemImpressao': '8'},...
# 3                                                                                                                                                                           {'TipoEvento': 'Atualização', 'DataEvento': '31/01/2015', 'OrdemImpressao': '8'}
#
#                                                                                                                                                                                                                                               MembrosBlocoSF  \
# 0  [{'UnidadePartidaria': 'Bloco Parlamentar Democracia', 'NumeroMembros': '8', 'PartidosBloco': {'Partidos': [{'SiglaPartido': 'UNIÃO'}, {'SiglaPartido': 'MDB'}, {'SiglaPartido': 'PODEMOS'}, {'SiglaPartido': 'PDT'}, {'SiglaPartido': 'PSDB'}]}, 'Mem...
# 1  [{'NumeroMembros': '2', 'MembrosSF': {'Membro': [{'ProprietarioVaga': 'Representante das empresas de rádio (inciso I)', 'NomeParlamentar': 'Flavio Lara Resende', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'Prop...
# 2                                                                                                                                                                                                                                                       None
# 3                                                                                                                                                           [{'UnidadePartidaria': 'MDB'}, {'UnidadePartidaria': 'PDT'}, {'UnidadePartidaria': 'PTB'}, None]
#
#                                                                                                                                                                                                                                               MembrosBlocoCD  \
# 0  [{'UnidadePartidaria': 'PL', 'NumeroMembros': '10', 'MembrosCD': {'Membro': [{'ProprietarioVaga': 'PL', 'NomeParlamentar': 'Deputado Giovani Cherini', 'CodigoParlamentar': '5336', 'CodigoDeputadoNaCamara': '160673', 'SiglaUf': 'RS', 'Partido': 'P...
# 1                                                                                                                                                                                                                                                       None
# 2                                                                                                                                                                                                                                                       None
# 3                                                                                                                                                                                                                                                       None
#
#                                                                                                                                                                                                               EventosProrrogacao  \
# 0  {'Leitura': '02/02/2015', 'TipoEvento': {'Membro': [{'TipoEvento': 'Designação', 'DatEvento': '11/07/2023', 'CodigoColegiado': '1916'}, {'TipoEvento': 'Instalação', 'DatEvento': '13/09/2023', 'CodigoColegiado': '1916'}]}}
# 1                                                                                                                                                                                                      {'Leitura': '30/12/1991'}
# 2                                                                                                                                                                                                      {'Leitura': '23/11/1972'}
# 3                                                                                                                                                                                                      {'Leitura': '12/08/1999'}
#
#                                                                                                                                                                                                                                              ObservacoesVaga  \
# 0  [{'Linha': '1', 'ObservacaoParlamentar': '11/07/2023: Designado como suplente o Senador Wellington Fagundes, conforme ATCN 49/2023 e Ofício n° 125/2023 do Bloco Vanguarda.'}, {'Linha': '2', 'ObservacaoParlamentar': '11/07/2023: Designado como tit...
# 1                                                                                                                                                                                                                                                       None
# 2                                                                                                                                                                                                                                                       None
# 3                                                                                                                                                                                                                                                       None
#
#                                          InformacoesSecretaria TipoColegiado  \
# 0                                 Antônio Ferreira Costa Filho         Órgão
# 1                                     SECRETARIA-GERAL DA MESA      Conselho
# 2  Núcleo de Premiações, Frentes e Grupos Parlamentares - NPFG      Conselho
# 3  Núcleo de Premiações, Frentes e Grupos Parlamentares - NPFG      Conselho
#
#                                                                                                                                         DescricaoSubtitulo
# 0                                                                                                                                                     None
# 1                                                         Lei nº 8.389, de 1991,\n      Regimento Interno aprovado nos termos do Ato da Mesa nº 1, de 2013
# 2                                                                              Decreto Legislativo nº 70, de 1972, regulamentado pelo Ato nº 1, de 1973-CN
# 3  Resolução do Senado Federal nº 2, de 1999-CN, regulamentada pelo Ato Conjunto dos Presidentes do Senado Federal e da Câmara dos Deputados nº 2, de 2001

# %%
def membros(lista):
    lista.fillna("", inplace=True)
    todosMembros = pd.DataFrame()
    for i,r in lista.iterrows():
        if r["MembrosBlocoSF"] is not None:
            for i,membros in enumerate(r["MembrosBlocoSF"]):
                if membros is not None:
                    iteracao = pd.DataFrame.from_dict(membros,orient='index').T
                    print((iteracao["MembrosSF"]))
                    
                    # iteracao["CodigoColegiado"] = r["CodigoColegiado"]
                    todosMembros = pd.concat([iteracao,todosMembros])
    return todosMembros.reset_index()

# %%
teste = membros(lista)
# Out:
# 0    {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Democracia', 'NomeParlamentar': 'Senador Renan Calheiros', 'CodigoParlamentar': '70', 'SiglaUf': 'AL', 'Partido': 'MDB', 'Ramais': '2261 / 2299', 'ObservacaoParlamentar': '2', 'TipoVaga': 'Titul...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar da Resistência Democrática', 'NomeParlamentar': 'Senador Sérgio Petecão', 'CodigoParlamentar': '4560', 'SiglaUf': 'AC', 'Partido': 'PSD', 'Ramais': '4086 / 6709', 'ObservacaoParlamentar': '9', '...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Aliança', 'NomeParlamentar': 'Senadora Tereza Cristina', 'CodigoParlamentar': '5736', 'SiglaUf': 'MS', 'Partido': 'PP', 'Ramais': '2431', 'ObservacaoParlamentar': '15', 'TipoVaga': 'Titular', 'N...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Vanguarda', 'NomeParlamentar': 'Senador Eduardo Girão', 'CodigoParlamentar': '5976', 'SiglaUf': 'CE', 'Partido': 'NOVO', 'Ramais': '6677 / 6679', 'ObservacaoParlamentar': '17', 'TipoVaga': 'Titu...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante das empresas de rádio (inciso I)', 'NomeParlamentar': 'Flavio Lara Resende', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das emp...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante das empresas de televisão (inciso II)', 'NomeParlamentar': 'João Camilo Júnior', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante das empresas de imprensa escrita (inciso III)', 'NomeParlamentar': 'VAGO', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das empre...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Engenheiro com notórios conhecimentos na área de comunicação social (inciso IV)', 'NomeParlamentar': 'Valderez de Almeida Donzelli', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos jornalistas (inciso V)', 'NomeParlamentar': 'Maria José Braga', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Repr...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos radialistas (inciso VI)', 'NomeParlamentar': 'José Antônio de Jesus da Silva', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'Proprieta...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos artistas (inciso VII)', 'NomeParlamentar': 'VAGO', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante da ...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante das categorias profissionais de cinema e vídeo (inciso VIII)', 'NomeParlamentar': 'Sonia Santana', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': ...
# Name: MembrosSF, dtype: object
# 0    {'Membro': [{'ProprietarioVaga': 'Representante da sociedade civil (inciso IX)', 'NomeParlamentar': 'Miguel Matos', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante da sociedade civ...
# Name: MembrosSF, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MembrosSF'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 teste = membros(lista)
#
# Cell In[77], line 9, in membros(lista)
#       7 if membros is not None:
#       8     iteracao = pd.DataFrame.from_dict(membros,orient='index').T
# ----> 9     print((iteracao["MembrosSF"]))
#      11     # iteracao["CodigoColegiado"] = r["CodigoColegiado"]
#      12     todosMembros = pd.concat([iteracao,todosMembros])
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'MembrosSF'

# %%
teste
# Out:
#     index                             UnidadePartidaria CodigoColegiado  \
# 0       0                                           PTB             769
# 1       0                                           PDT             769
# 2       0                                           MDB             769
# 3       0                                           NaN             767
# 4       0                                           NaN             767
# 5       0                                           NaN             767
# 6       0                                           NaN             767
# 7       0                                           NaN             767
# 8       0                                           NaN             767
# 9       0                                           NaN             767
# 10      0                                           NaN             767
# 11      0                                           NaN             767
# 12      0                   Bloco Parlamentar Vanguarda            1916
# 13      0                     Bloco Parlamentar Aliança            1916
# 14      0  Bloco Parlamentar da Resistência Democrática            1916
# 15      0                  Bloco Parlamentar Democracia            1916
#
#    NumeroMembros  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3             10
# 4              2
# 5              2
# 6              2
# 7              2
# 8              2
# 9              2
# 10             2
# 11             2
# 12             2
# 13             2
# 14             8
# 15             8
#
#                                                                                                                                                                                                                                                     MembrosSF  \
# 0                                                                                                                                                                                                                                                         NaN
# 1                                                                                                                                                                                                                                                         NaN
# 2                                                                                                                                                                                                                                                         NaN
# 3   {'Membro': [{'ProprietarioVaga': 'Representante da sociedade civil (inciso IX)', 'NomeParlamentar': 'Miguel Matos', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante da sociedade civ...
# 4   {'Membro': [{'ProprietarioVaga': 'Representante das categorias profissionais de cinema e vídeo (inciso VIII)', 'NomeParlamentar': 'Sonia Santana', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': ...
# 5   {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos artistas (inciso VII)', 'NomeParlamentar': 'VAGO', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante da ...
# 6   {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos radialistas (inciso VI)', 'NomeParlamentar': 'José Antônio de Jesus da Silva', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'Proprieta...
# 7   {'Membro': [{'ProprietarioVaga': 'Representante da categoria profissional dos jornalistas (inciso V)', 'NomeParlamentar': 'Maria José Braga', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Repr...
# 8   {'Membro': [{'ProprietarioVaga': 'Engenheiro com notórios conhecimentos na área de comunicação social (inciso IV)', 'NomeParlamentar': 'Valderez de Almeida Donzelli', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {...
# 9   {'Membro': [{'ProprietarioVaga': 'Representante das empresas de imprensa escrita (inciso III)', 'NomeParlamentar': 'VAGO', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das empre...
# 10  {'Membro': [{'ProprietarioVaga': 'Representante das empresas de televisão (inciso II)', 'NomeParlamentar': 'João Camilo Júnior', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das...
# 11  {'Membro': [{'ProprietarioVaga': 'Representante das empresas de rádio (inciso I)', 'NomeParlamentar': 'Flavio Lara Resende', 'TipoVaga': 'Titular', 'NumeroOrdem': '1', 'OrigemParlamentar': 'Congresso'}, {'ProprietarioVaga': 'Representante das emp...
# 12  {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Vanguarda', 'NomeParlamentar': 'Senador Eduardo Girão', 'CodigoParlamentar': '5976', 'SiglaUf': 'CE', 'Partido': 'NOVO', 'Ramais': '6677 / 6679', 'ObservacaoParlamentar': '17', 'TipoVaga': 'Titu...
# 13  {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Aliança', 'NomeParlamentar': 'Senadora Tereza Cristina', 'CodigoParlamentar': '5736', 'SiglaUf': 'MS', 'Partido': 'PP', 'Ramais': '2431', 'ObservacaoParlamentar': '15', 'TipoVaga': 'Titular', 'N...
# 14  {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar da Resistência Democrática', 'NomeParlamentar': 'Senador Sérgio Petecão', 'CodigoParlamentar': '4560', 'SiglaUf': 'AC', 'Partido': 'PSD', 'Ramais': '4086 / 6709', 'ObservacaoParlamentar': '9', '...
# 15  {'Membro': [{'ProprietarioVaga': 'Bloco Parlamentar Democracia', 'NomeParlamentar': 'Senador Renan Calheiros', 'CodigoParlamentar': '70', 'SiglaUf': 'AL', 'Partido': 'MDB', 'Ramais': '2261 / 2299', 'ObservacaoParlamentar': '2', 'TipoVaga': 'Titul...
#
#                                                                                                                                          PartidosBloco
# 0                                                                                                                                                  NaN
# 1                                                                                                                                                  NaN
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
# 5                                                                                                                                                  NaN
# 6                                                                                                                                                  NaN
# 7                                                                                                                                                  NaN
# 8                                                                                                                                                  NaN
# 9                                                                                                                                                  NaN
# 10                                                                                                                                                 NaN
# 11                                                                                                                                                 NaN
# 12                                                                                    {'Partidos': [{'SiglaPartido': 'PL'}, {'SiglaPartido': 'NOVO'}]}
# 13                                                                            {'Partidos': [{'SiglaPartido': 'PP'}, {'SiglaPartido': 'REPUBLICANOS'}]}
# 14                                  {'Partidos': [{'SiglaPartido': 'REDE'}, {'SiglaPartido': 'PT'}, {'SiglaPartido': 'PSB'}, {'SiglaPartido': 'PSD'}]}
# 15  {'Partidos': [{'SiglaPartido': 'UNIÃO'}, {'SiglaPartido': 'MDB'}, {'SiglaPartido': 'PODEMOS'}, {'SiglaPartido': 'PDT'}, {'SiglaPartido': 'PSDB'}]}

# %%
membrot = teste.iloc[3]["MembrosSF"]

# %%
type(membrot["Membro"])
# Out:
# list
